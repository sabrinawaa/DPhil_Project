# %%
import pybdsim
# import pyg4ometry.geant4 as g4
# from pyg4ometry import gdml
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt
import RF_Track as rft
# Out:
# Warning in <TFile::Init>: no StreamerInfo found in /opt/anaconda3/envs/bdsim/lib/BDSBH4DBaseDict_rdict.pcm therefore preventing schema evolution when reading this file. The file was produced with ROOT version 6.30/02, while the current version is 6.34.04
# Warning in <TFile::Init>: no StreamerInfo found in /opt/anaconda3/envs/bdsim/lib/BDSBH4DDict_rdict.pcm therefore preventing schema evolution when reading this file. The file was produced with ROOT version 6.30/02, while the current version is 6.34.04
# Warning in <TFile::Init>: no StreamerInfo found in /opt/anaconda3/envs/bdsim/lib/BDSOutputROOTEventApertureDict_rdict.pcm therefore preventing schema evolution when reading this file. The file was produced with ROOT version 6.30/02, while the current version is 6.34.04
# Error in cling::AutoLoadingVisitor::InsertIntoAutoLoadingState:
#    Missing FileEntry for ../parser/beamBase.h
#    requested to autoload type GMAD::BeamBase
# ...

# %%
e = pybdsim.Element()
e.name = "collimator"
e.type = bdsim.ElementType.RCOL
e.l = 0.05
e.xsize = 0.0
e.ysize = 0.0
e.material = "G4_Fe"
e = pybdsim.rftrack.BDSIMElement(e)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 e = pybdsim.Element()
#       2 e.name = "collimator"
#       3 e.type = bdsim.ElementType.RCOL
#
# AttributeError: module 'pybdsim' has no attribute 'Element'

# %%
e = bdsim.rftrack.BDSIMElement(e)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 e = bdsim.rftrack.BDSIMElement(e)
#
# AttributeError: module 'bdsim' has no attribute 'rftrack'

# %%
bdsim.
